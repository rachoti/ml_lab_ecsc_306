# %%
import tensorflow as tf

x = tf.Variable([1.1,2.2,3.3])

init1 = tf.global_variables_initializer()

sess = tf.Session()

sess.run(init1)


xsum = tf.reduce_sum(x)

xmean = tf.divide(xsum,3)

subsx=tf.subtract(x,xmean)

mulx=tf.multiply(subsx,subsx)
subsy=tf.subtract(y,ymean)

muly=tf.multiply(subsy,subsy)
mulxy=tf.multiply(subsx,subsy)
covxy=tf.reduce_sum(mulxy)

print(sess.run(covxy))


xsum = tf.reduce_sum(mulx)
ysum = tf.reduce_sum(muly)


xmean = tf.divide(xsum,3)

print(sess.run(xmean))
print(sess.run(xsum))


#$$covariance = sum((x(i) - mean(x)) * (y(i) - mean(y)))$$
m=tf.divide(covxy,xsum)
print(sess.run(m))
#$$m = covariance(x,y)/variance(x)$$
subc=tf.subtract(ymean,m)
c=tf.multiply(subc,xmean)
print(sess.run(c))

#$$c = mean(y) -m* mean(x)$$

# %%
import tensorflow as tf

x = tf.Variable([1.1,2.2,3.3])

init1 = tf.global_variables_initializer()

sess = tf.Session()

sess.run(init1)


xsum = tf.reduce_sum(x)

xmean = tf.divide(xsum,3)

subs=tf.subtract(x,xmean)

mul=tf.multiply(subs,subs)


xsum = tf.reduce_sum(mul)

xmean = tf.divide(xsum,3)

print(sess.run(xmean))

# %%
import tensorflow as tf

x = tf.Variable([1.1,2.2,3.3])
init1 = tf.global_variables_initializer()

sess = tf.Session()
sess.run(init1)

y = tf.Variable([4.4,5.5,6.6])
init2 = tf.global_variables_initializer()

sess = tf.Session()
sess.run(init2)

print(sess.run(tf.reduce_sum(x)))

print(sess.run(tf.reduce_sum(y)))

xsum = tf.reduce_sum(x)
xmean = tf.divide(xsum,3)
print(sess.run(xmean))
ysum = tf.reduce_sum(y)
ymean = tf.divide(ysum,3)
print(sess.run(ymean))

# %%
import tensorflow as tf

x = tf.Variable([1.1,2.2,3.3])

init1 = tf.global_variables_initializer()

sess = tf.Session()

sess.run(init1)


xsum = tf.reduce_sum(x)

xmean = tf.divide(xsum,3)

subsx=tf.subtract(x,xmean)

mulx=tf.multiply(subsx,subsx)
subsy=tf.subtract(y,ymean)

muly=tf.multiply(subsy,subsy)
mulxy=tf.multiply(subsx,subsy)
covxy=tf.reduce_sum(mulxy)

print(sess.run(covxy))


xsum = tf.reduce_sum(mulx)
ysum = tf.reduce_sum(muly)


xmean = tf.divide(xsum,3)

print(sess.run(xmean))



#$$covariance = sum((x(i) - mean(x)) * (y(i) - mean(y)))$$

# %%
import tensorflow as tf

x =tf.constant([5.2,1.7,8.9,4.3])
sum_x= tf.reduce_sum(x)
mean_x=tf.reduce_mean(x)

y =tf.constant([7.9,49.4,78.5,2.5])
sum_y= tf.reduce_sum(y)
mean_y=tf.reduce_mean(y)


init1 = tf.global_variables_initializer()
session = tf.Session()
session.run(init1)

sub_x=tf.subtract(x,mean_x)
mx=tf.multiply(sub_x,sub_x)

sub_y=tf.subtract(y,mean_y)
my=tf.multiply(sub_y,sub_y)


xy=tf.multiply(sub_x,sub_y)
cxy=tf.reduce_sum(xy)

print(session.run(cxy))


xsum = tf.reduce_sum(mx)
ysum = tf.reduce_sum(my)


m = tf.divide(xsum,4)

print(session.run(m))
print(session.run(xsum))

m1=tf.divide(cxy,xsum)
print(session.run(m))

subc=tf.subtract(mean_y,m1)
c=tf.multiply(subc,m)
print(session.run(c))
writer = tf.summary.FileWriter("/tmp/tboard/output_rachayya", session.graph)
# Out:
# 139.502
# 6.65687
# 26.6275
# 6.65687
# 195.286
